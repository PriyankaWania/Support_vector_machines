# %%
# Plotting the results of different parameters used for training the SVM model

import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import accuracy_score
#packages for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import pickle

# %%
dataset = pd.read_csv('C:\\Users\\prian\\Desktop\\Data.csv')
dataset.head()
# Out:
#    Samples  SSIP      SDFP      SDFB   SFE   RFIP  TYPE
# 0      1.0  12.0  0.532204  2.992085  25.0  100.0   0.0
# 1      2.0  13.0  0.835165  3.510189  26.0  100.0   0.0
# 2      3.0  13.0  0.714143  3.076808  26.0  100.0   0.0
# 3      4.0  11.0  0.588235  3.349963  22.0  100.0   0.0
# 4      5.0  12.0  0.644899  3.299048  24.0  100.0   0.0

# %%
samples = dataset.iloc[:,0]
SSIP = dataset.iloc[:,1]

# %%
plt.plot(samples, SSIP)
plt.xlabel('Samples')
plt.ylabel('Speed of source IP')
plt.title('Observing Speed of Source IP')
# Out:
# Text(0.5,1,'Observing Speed of Source IP')

# %%
SDFP = dataset.iloc[:,2]
plt.plot(samples, SDFP)
plt.xlabel('Samples')
plt.ylabel('Standard Deviation of Flow Packets')
# Out:
# Text(0,0.5,'SDFP')

# %%
SDFB = dataset.iloc[:,3]
plt.plot(samples, SDFB)
plt.xlabel('Samples')
plt.ylabel('Standard Deviation of Flow Bytes')
plt.title('Observing Speed of Standard Deviation of Flow Bytes and packets')
# Out:
# Text(0.5,1,'Observing Speed of Standard Deviation of Flow Bytes and packets')

# %%
SFE = dataset.iloc[:,4]
plt.plot(samples, SFE)
plt.xlabel('Samples')
plt.ylabel('Speed of Flow Entries')
plt.title('Observing Speed of Flow Entries')
# Out:
# Text(0.5,1,'Observing Speed of Flow Entries')

# %%
RFIP = dataset.iloc[:,5]
plt.plot(samples, RFIP)
plt.xlabel("Samples")
plt.ylabel("Ratio of Pair-Flow Entries")
plt.title('Observing Ratio of Pair-Flow Entries')
# Out:
# Text(0.5,1,'Observing Ratio of Pair-Flow Entries')
